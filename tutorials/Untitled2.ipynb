# %%
import pandas as pd

# %%
df = pd.read_csv('anika.csv', delimiter = ',')
df
df.values
# Out:
# array([[  0, 412, 453, 501],
#        [  0, 412, 453, 501],
#        [  0, 412, 453, 501],
#        ...,
#        [600, 628, 665, 697],
#        [600, 628, 665, 697],
#        [600, 628, 665, 697]])

# %%
df.shape
# Out:
# (219802, 4)

# %%
df1 = pd.read_csv('M1_test1.csv', delimiter = ',')
df1
# Out:
#        or_x  or_y  height  width
# 0         0     0     453     89
# 1         0     0     453     89
# 2         0     0     453     89
# 3         0     0     453     89
# 4         0     0     453     89
# 5         0     0     453     89
# 6         0     0     453     89
# 7         0     0     453     89
# 8         0     0     453     89
# 9         0     0     453     89
# 10        0     0     453     89
# 11        0     0     453     89
# 12        0     0     453     89
# 13        0     0     453     89
# 14        0     0     453     89
# 15        0     0     453     89
# 16        0     0     453     89
# 17        0     0     453     89
# 18        0     0     453     89
# 19        0     0     453     89
# 20        0     0     453     89
# 21        0     0     453     89
# 22        0     0     453     89
# 23        0     0     453     89
# 24        0     0     453     89
# 25        0     0     453     89
# 26        0     0     453     89
# ...

# %%
df1
# Out:
#        or_x  or_y  height  width
# 0         0     0     453     89
# 1         0     0     453     89
# 2         0     0     453     89
# 3         0     0     453     89
# 4         0     0     453     89
# 5         0     0     453     89
# 6         0     0     453     89
# 7         0     0     453     89
# 8         0     0     453     89
# 9         0     0     453     89
# 10        0     0     453     89
# 11        0     0     453     89
# 12        0     0     453     89
# 13        0     0     453     89
# 14        0     0     453     89
# 15        0     0     453     89
# 16        0     0     453     89
# 17        0     0     453     89
# 18        0     0     453     89
# 19        0     0     453     89
# 20        0     0     453     89
# 21        0     0     453     89
# 22        0     0     453     89
# 23        0     0     453     89
# 24        0     0     453     89
# 25        0     0     453     89
# 26        0     0     453     89
# ...
